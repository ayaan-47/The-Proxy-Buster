# %%
import cv2
import numpy
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2
face_classifier = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')
image1 = cv2.imread('sampleraghav.jpg')

gray = cv2.cvtColor(image1,cv2.COLOR_BGR2GRAY) 

plt.imshow(cv2.cvtColor(gray,cv2.COLOR_BGR2RGB))

# %%
faces = face_classifier.detectMultiScale(gray, scaleFactor=1.2, minNeighbors=2) 
if len(faces)==0:
    print("No face Detected in the Image!")
for (x,y,w,h) in faces:
    cv2.rectangle(image1, (x,y), (x+w,y+h), (0,250,0), 6)
    plt.imshow(cv2.cvtColor(image1, cv2.COLOR_BGR2RGB))
print("Total number of Faces Detected : ",faces.shape[0])
    
    
cv2.destroyAllWindows()
# Out:
# Total number of Faces Detected :  1
