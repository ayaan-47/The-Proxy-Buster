# %%
import cv2
import tensorflow
from mtcnn import MTCNN
import matplotlib.pyplot as plt
# %matplotlib inline

def detect_faces():
    # Load the image
    count = int(0)
    image = cv2.imread("science.jpg")

    
    # Convert to RGB (MTCNN expects RGB images)
    rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    # Create an instance of the MTCNN detector
    detector = MTCNN()
    
    # Detect faces in the image
    faces = detector.detect_faces(rgb_image)
    
    # Draw bounding boxes around the faces
    for face in faces:
        count = count+1
        x, y, w, h = face['box']
        cv2.rectangle(rgb_image, (x, y), (x+w, y+h), (0, 255, 0), 2)
        #     key_points = res['keypoints'].values()
        #     cv2.putText(img, f'conf: {confidence:.3f}', (x1, y1), cv2.FONT_ITALIC, 1, (0, 0, 255), 1)

        #     for point in key_points:
        #         cv2.circle(img, point, 5, (0, 0, 255), thickness=-1)
    
    # Display the image with faces detected
    cv2.imshow('Faces Detected', image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    print("Total Faces : ",count)
    plt.imshow(rgb_image)
#     if cv2.waitKey(1) & 0xff == ord(' '):
#         break


# Path to the image file
image_path = 'science.jpg'

# Call the function to detect faces
detect_faces()
# Out:
# ...
# 5/5 [==============================] - 0s 36ms/step
# Total Faces :  29

# %%
import mtcnn
import cv2

face_detector = mtcnn.MTCNN(min_face_size=50)

vc = cv2.VideoCapture(0)

while true():
    _,frame = vc.read()


    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    faces = face_detector.detect_faces(frame_rgb)

    for face in faces:
        x, y, w, h = face['box']
        cv2.rectangle(frame, (x, y), (x+h, y+w), (0, 100, 100), thickness=2)
#         left_eye = res['keypoints']['left_eye']
#         right_eye = res['keypoints']['right_eye']
#         mouth_left = res['keypoints']['mouth_left']
#         mouth_right = res['keypoints']['mouth_right']
#         nose = res['keypoints']['nose']

#         for eye in [left_eye, right_eye]:
#             cv2.rectangle(frame, (eye[0] - 15, eye[1] - 15), (eye[0] + 15, eye[1] + 15), (0, 100, 100), 2)
#         cv2.circle(frame, nose, 10, (0, 100, 100), thickness=-1)

#         cv2.rectangle(frame, (mouth_left[0] - 15, mouth_left[1] - 15), (mouth_right[0] + 15, mouth_right[1] + 15), (0, 100, 100), 2)
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)

    cv2.imshow(frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 8>()
#       4 face_detector = mtcnn.MTCNN(min_face_size=50)
#       6 vc = cv2.VideoCapture(0)
# ----> 8 while true():
#       9     _,frame = vc.read()
#      12     frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#
# NameError: name 'true' is not defined
